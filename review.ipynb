# %%
# import json
# from collections import Counter

# # Đọc file train.json từ local
# with open('train.json', 'r', encoding='utf-8') as f:
#     train_data = [json.loads(line) for line in f]

# # Lấy danh sách Toxicity từ train data
# toxicity_values = [item["Toxicity"] for item in train_data]

# # Đếm số lượng
# Counter(toxicity_values)
# Out:
# Counter({0: 6241, 1: 759})

# %%
#Test input for EDA & imbalance discussion
from collections import Counter
import json

counter = Counter()

with open("data/processed/victsd_v1/train.jsonl", encoding="utf-8") as f:
    for line in f:
        counter[json.loads(line)["label"]] += 1

print(counter)
# Out:
# Counter({0: 6241, 1: 759})
